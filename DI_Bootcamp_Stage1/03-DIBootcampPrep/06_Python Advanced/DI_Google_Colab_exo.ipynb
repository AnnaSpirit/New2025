# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaSpirit/New2025/blob/master/DI_Google_Colab_exo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Create a simple DataFrame
df = pd.DataFrame(np.random.randn(5, 3), columns=['A', 'B', 'C'])
print(df)
# Out:
#           A         B         C
# 0 -1.288694  0.380290  0.957378
# 1  0.895193  0.351113 -0.264240
# 2  1.131407  0.444400  0.048598
# 3 -0.482741 -0.810371 -0.847173
# 4 -1.666716 -0.523860 -0.266596

# %% [markdown]
# Lien de l'exercice: https://octopus.developers.institute/courses/collection/83/course/618/section/1688/chapter/4270
